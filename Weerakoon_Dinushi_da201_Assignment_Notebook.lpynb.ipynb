# %% [markdown]
# ### LSE Data Analytics Online Career Accelerator
#
# # Course 2: Data Analytics using Python

# %% [markdown]
# ## Assignment: Diagnostic Analysis using Python
#
# You’ll be working with real-world data to address a problem faced by the National Health Service (NHS). The analysis will require you to utilise Python to explore the available data, create visualisations to identify trends, and extract meaningful insights to inform decision-making.

# %% [markdown]
# ### A note for students using this template
# This Jupyter Notebook is a template you can use to complete the Course 2 assignment: Diagnostic Analysis using Python.
#
# Keep in mind:
# - You are **not required** to use this template to complete the assignment.
# - If you decide to use this template for your assignment, make a copy of the notebook and save it using the assignment naming convention: **LastName_FirstName_DA201_Assignment_Notebook.ipynb**.
# - The workflow suggested in this template follows the Assignment Activities throughout the course.
# - Refer to the guidance on the Assignment Activity pages for specific details.
# - The markup and comments in this template identify the key elements you need to complete before submitting the assignment.
# - Make this notebook your own by adding your process notes and rationale using markdown, add links, screenshots, or images to support your analysis, refine or clarify the comments, and change the workflow to suit your process.
# - All elements should be functional and visible in your Notebook.
# - Be sure to push your notebook to GitHub after completing each Assignment Activity.
#
#  > ***Markdown*** Remember to change cell types to `Markdown`. You can review [Markdown basics](https://docs.github.com/en/get-started/writing-on-github/getting-started-with-writing-and-formatting-on-github/basic-writing-and-formatting-syntax) to find out how to add formatted text, links, and images to your notebook.

# %% [markdown]
# #

# %% [markdown]
# # Assignment activity 1

# %% [markdown]
# ### Insert proof of your GitHub repository. This can be a link or screenshot showing your repo.

# %%
# My GitHub repository.

# %% [markdown]
# ##### https://github.com/romeewee

# %% [markdown]
# Github is a platform to share own works and to easy collaboration and file saving.

# %% [markdown]
# # Assignment activity 2

# %% [markdown]
# ### Prepare your workstation

# %%
# Import the necessary libraries.
import pandas as pd
import numpy as np

# Optional - Ignore warnings.
import warnings
warnings.filterwarnings('ignore')

# %%
# Import and sense-check the actual_duration.csv data set as ad.
# Use the pd.read_csv() function.
# Read the CSV file.
# Specify the name of the CSV file.
ad = pd.read_csv('actual_duration.csv')

# View the DataFrame.
ad
# Out:
#        sub_icb_location_code sub_icb_location_ons_code  \
# 0                        00L                 E38000130
# 1                        00L                 E38000130
# 2                        00L                 E38000130
# 3                        00L                 E38000130
# 4                        00L                 E38000130
# ...                      ...                       ...
# 137788                 X2C4Y                 E38000254
# 137789                 X2C4Y                 E38000254
# 137790                 X2C4Y                 E38000254
# 137791                 X2C4Y                 E38000254
# 137792                 X2C4Y                 E38000254
#
#                              sub_icb_location_name icb_ons_code  \
# 0       NHS North East and North Cumbria ICB - 00L    E54000050
# 1       NHS North East and North Cumbria ICB - 00L    E54000050
# 2       NHS North East and North Cumbria ICB - 00L    E54000050
# ...

# %% [markdown]
# Showing the whole data set instead of showing only the head help to familiarize with the full data frames, names, columns present and sizes.

# %%
# Sense-check the column names, number of rows and columns, data types
print('actual_duration.csv')
print(ad.columns)  #Column names
print(ad.shape)    #Number of rows and columns
print(ad.dtypes)   #Data types
# Out:
# actual_duration.csv:
# Index(['sub_icb_location_code', 'sub_icb_location_ons_code',
#        'sub_icb_location_name', 'icb_ons_code', 'region_ons_code',
#        'appointment_date', 'actual_duration', 'count_of_appointments'],
#       dtype='object')
# (137793, 8)
# sub_icb_location_code        object
# sub_icb_location_ons_code    object
# sub_icb_location_name        object
# icb_ons_code                 object
# region_ons_code              object
# appointment_date             object
# actual_duration              object
# count_of_appointments         int64
# dtype: object

# %% [markdown]
# Helps to familiarize with the context type.

# %%
# Determine whether there are missing values.
print(ad.isnull().sum())  # Number of missing values
# Out:
# sub_icb_location_code        0
# sub_icb_location_ons_code    0
# sub_icb_location_name        0
# icb_ons_code                 0
# region_ons_code              0
# appointment_date             0
# actual_duration              0
# count_of_appointments        0
# dtype: int64

# %% [markdown]
# This function is used to fix in case of any missing data the dataset.

# %%
# Determine the metadata of the data set.
print('Descriptive statistics of actual_duration.csv')
print(ad.info())
# Out:
# Descriptive statistics of actual_duration.csv:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137793 entries, 0 to 137792
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   sub_icb_location_code      137793 non-null  object
#  1   sub_icb_location_ons_code  137793 non-null  object
#  2   sub_icb_location_name      137793 non-null  object
#  3   icb_ons_code               137793 non-null  object
#  4   region_ons_code            137793 non-null  object
#  5   appointment_date           137793 non-null  object
#  6   actual_duration            137793 non-null  object
#  7   count_of_appointments      137793 non-null  int64
# dtypes: int64(1), object(7)
# memory usage: 8.4+ MB
# None

# %%
# Determine the descriptive statistics of the data set.
print('Descriptive statistics of actual_duration.csv')
print(ad.describe())
# Out:
# Descriptive statistics of actual_duration.csv:
#        count_of_appointments
# count          137793.000000
# mean             1219.080011
# std              1546.902956
# min                 1.000000
# 25%               194.000000
# 50%               696.000000
# 75%              1621.000000
# max             15400.000000

# %%
# Import and sense-check the appointments_regional.csv data set as ar.
# Read the CSV file.
# Use the pd.read_csv() function.
# Specify the name of the CSV file.
ar = pd.read_csv('appointments_regional.csv')

# View the DataFrame.
ar
# Out:
#        icb_ons_code appointment_month appointment_status hcp_type  \
# 0         E54000034           2020-01           Attended       GP
# 1         E54000034           2020-01           Attended       GP
# 2         E54000034           2020-01           Attended       GP
# 3         E54000034           2020-01           Attended       GP
# 4         E54000034           2020-01           Attended       GP
# ...             ...               ...                ...      ...
# 596816    E54000050           2022-06            Unknown  Unknown
# 596817    E54000050           2022-06            Unknown  Unknown
# 596818    E54000050           2022-06            Unknown  Unknown
# 596819    E54000050           2022-06            Unknown  Unknown
# 596820    E54000050           2022-06            Unknown  Unknown
#
#        appointment_mode time_between_book_and_appointment  \
# 0          Face-to-Face                             1 Day
# ...

# %%
# Sense-check the column names, number of rows and columns, data types
print('appointments_regional.csv')
print(ar.columns)  #Column names
print(ar.shape)    #Number of rows and columnsprint(ar.dtypes)   
print(ar.dtypes)   #Data types
# Out:
# appointments_regional.csv
# Index(['icb_ons_code', 'appointment_month', 'appointment_status', 'hcp_type',
#        'appointment_mode', 'time_between_book_and_appointment',
#        'count_of_appointments'],
#       dtype='object')
# (596821, 7)
# icb_ons_code                         object
# appointment_month                    object
# appointment_status                   object
# hcp_type                             object
# appointment_mode                     object
# time_between_book_and_appointment    object
# count_of_appointments                 int64
# dtype: object

# %%
# Determine whether there are missing values.
print(ar.isnull().sum())  # Number of missing values
# Out:
# icb_ons_code                         0
# appointment_month                    0
# appointment_status                   0
# hcp_type                             0
# appointment_mode                     0
# time_between_book_and_appointment    0
# count_of_appointments                0
# dtype: int64

# %%
# Determine the metadata of the data set.
print('Descriptive statistics of appointments_regional.csv')
print(ar.info())
# Out:
# Descriptive statistics of appointments_regional.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 596821 entries, 0 to 596820
# Data columns (total 7 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   icb_ons_code                       596821 non-null  object
#  1   appointment_month                  596821 non-null  object
#  2   appointment_status                 596821 non-null  object
#  3   hcp_type                           596821 non-null  object
#  4   appointment_mode                   596821 non-null  object
#  5   time_between_book_and_appointment  596821 non-null  object
#  6   count_of_appointments              596821 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 31.9+ MB
# None

# %%
# Determine the descriptive statistics of the data set.
print('Descriptive statistics of appointments_regional.csv')
print(ar.describe())
# Out:
# Descriptive statistics of appointments_regional.csv
#        count_of_appointments
# count          596821.000000
# mean             1244.601857
# std              5856.887042
# min                 1.000000
# 25%                 7.000000
# 50%                47.000000
# 75%               308.000000
# max            211265.000000

# %%
# Import and sense-check the national_categories.xlsx data set as nc.
# Read the CSV file.
# Use the pd.read_csv() function.
# Specify the name of the CSV file.
nc = pd.read_excel('national_categories.xlsx')

# View the DataFrame.
nc
# Out:
#        appointment_date icb_ons_code  \
# 0            2021-08-02    E54000050
# 1            2021-08-02    E54000050
# 2            2021-08-02    E54000050
# 3            2021-08-02    E54000050
# 4            2021-08-02    E54000050
# ...                 ...          ...
# 817389       2022-06-30    E54000054
# 817390       2022-06-30    E54000054
# 817391       2022-06-30    E54000054
# 817392       2022-06-30    E54000054
# 817393       2022-06-30    E54000054
#
#                              sub_icb_location_name            service_setting  \
# 0       NHS North East and North Cumbria ICB - 00L       Primary Care Network
# 1       NHS North East and North Cumbria ICB - 00L                      Other
# 2       NHS North East and North Cumbria ICB - 00L           General Practice
# 3       NHS North East and North Cumbria ICB - 00L           General Practice
# 4       NHS North East and North Cumbria ICB - 00L           General Practice
# ...

# %%
# Sense-check the column names, number of rows and columns, data types
print('national_categories.xlsx')
print(nc.columns)  #Column names
print(nc.shape)    #Number of rows and columns
print(nc.dtypes)   #Data types
# Out:
# national_categories.xlsx
# Index(['appointment_date', 'icb_ons_code', 'sub_icb_location_name',
#        'service_setting', 'context_type', 'national_category',
#        'count_of_appointments', 'appointment_month'],
#       dtype='object')
# (817394, 8)
# appointment_date         datetime64[ns]
# icb_ons_code                     object
# sub_icb_location_name            object
# service_setting                  object
# context_type                     object
# national_category                object
# count_of_appointments             int64
# appointment_month                object
# dtype: object

# %%
# Determine whether there are missing values.
print(nc.isnull().sum())  # Number of missing values
# Out:
# appointment_date         0
# icb_ons_code             0
# sub_icb_location_name    0
# service_setting          0
# context_type             0
# national_category        0
# count_of_appointments    0
# appointment_month        0
# dtype: int64

# %%
# Determine the metadata of the data set.
print('Descriptive statistics of national_categories.xlsx')
print(nc.info())
# Out:
# Descriptive statistics of national_categories.xlsx
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 817394 entries, 0 to 817393
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   appointment_date       817394 non-null  datetime64[ns]
#  1   icb_ons_code           817394 non-null  object
#  2   sub_icb_location_name  817394 non-null  object
#  3   service_setting        817394 non-null  object
#  4   context_type           817394 non-null  object
#  5   national_category      817394 non-null  object
#  6   count_of_appointments  817394 non-null  int64
#  7   appointment_month      817394 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 49.9+ MB
# None

# %%
# Determine the descriptive statistics of the data set.
print('Descriptive statistics of national_categories.xlsx')
print(nc.describe())
# Out:
# Descriptive statistics of national_categories.xlsx
#        count_of_appointments
# count          817394.000000
# mean              362.183684
# std              1084.576600
# min                 1.000000
# 25%                 7.000000
# 50%                25.000000
# 75%               128.000000
# max             16590.000000

# %% [markdown]
# ### Explore the data set

# %% [markdown]
# **Question 1:** How many locations are there in the data set?

# %%
# Determine the number of locations.

# The count method values in the 'sub_icb_location_name' column
sub_icb_location_counts = nc['sub_icb_location_name'].value_counts()

# Count of unique values in the 'sub_icb_location_name' column and print with text 'Number of location'
num_locations=nc['sub_icb_location_name'].nunique()
print("Number of location",num_locations)
# Out:
# Number of location 106

# %% [markdown]
# From the national categories xlsx extracting thrught the process describe with # the numbers of location present in the file to understand in how many locations NHS provide services according to this specific dataset.

# %% [markdown]
# **Question 2:** What are the five locations with the highest number of records?

# %%
# Determine the top five locations based on record count.

top_locations = nc['sub_icb_location_name'].value_counts().head(5)
print("Top 5 locations with the highest number of records:")
print(top_locations)
# Out:
# Top 5 locations with the highest number of records:
# NHS North West London ICB - W2U3Z              13007
# NHS Kent and Medway ICB - 91Q                  12637
# NHS Devon ICB - 15N                            12526
# NHS Hampshire and Isle Of Wight ICB - D9Y0V    12171
# NHS North East London ICB - A3A8R              11837
# Name: sub_icb_location_name, dtype: int64

# %% [markdown]
# As a next step it is identify which are the Nhs locations which has the higher number of records on the file analized.

# %% [markdown]
# **Question 3:** How many service settings, context types, national categories, and appointment statuses are there?

# %%
# Determine the number of service settings.
# Determine the number of context types.
# Determine the number of national categories.
# Determine the number of appointment status.

num_service_settings = nc['service_setting'].nunique()
num_context_types = nc['context_type'].nunique()
num_national_categories = nc['national_category'].nunique()
num_appointment_statuses = ar['appointment_status'].nunique()

print("Number of service settings:", num_service_settings)
print("Number of context types:", num_context_types)
print("Number of national categories:", num_national_categories)
print("Number of appointment statuses:", num_appointment_statuses)
# Out:
# Number of service settings: 5
# Number of context types: 3
# Number of national categories: 18
# Number of appointment statuses: 3

# %% [markdown]
# From the same file exploring the options under each column (for the paramiters requested). E.g. on the last line is identified appointment status are three: these refer to the three options, attended, not attended or unknown. For more info read the metadata to interpretate the numbers into text.

# %% [markdown]
# #

# %% [markdown]
# # Assignment activity 3

# %% [markdown]
# ### Continue to explore the data and search for answers to more specific questions posed by the NHS.

# %% [markdown]
# **Question 1:** Between what dates were appointments scheduled?

# %%
# View the first five rows of appointment_date for the ad DataFrame to determine the date format.

# Read the acual_duration.csv file into the ad DataFrame
# View the DataFrame
ad = pd.read_csv('actual_duration.csv')

# View the first five rows of appointment_date for the ad DataFrame to determine the date format.
print(ad['appointment_date'].head(5))
# Out:
# 0    01-Dec-21
# 1    01-Dec-21
# 2    01-Dec-21
# 3    01-Dec-21
# 4    01-Dec-21
# Name: appointment_date, dtype: object

# %%
# View the first five rows of appointment_date for the nc DataFrame to determine the date format.

# Read the national_categories.xlsx file into the nc DataFrame
# View the DataFrame
nc = pd.read_excel('national_categories.xlsx')

# View the first five rows of appointment_date for the nc DataFrame to determine the date format.
print(nc['appointment_date'].head(5))
# Out:
# 0   2021-08-02
# 1   2021-08-02
# 2   2021-08-02
# 3   2021-08-02
# 4   2021-08-02
# Name: appointment_date, dtype: datetime64[ns]

# %%
# Change the date format of ad file ['appointment_date'].
# Convert date columns to datetime format
ad['appointment_date'] = pd.to_datetime(ad['appointment_date'])

# Sense-check the DataFrames with dtypes and head()
# View only appoitnment_date column in ad DateFrame and printing relevant info in easy read 
print("DataFrames after converting date columns to datetime format:")
print(ad['appointment_date'].head(5))  # Check the updated actual_duration.csv DataFrame
# Out:
# DataFrames after converting date columns to datetime format:
# 0   2021-12-01
# 1   2021-12-01
# 2   2021-12-01
# 3   2021-12-01
# 4   2021-12-01
# Name: appointment_date, dtype: datetime64[ns]

# %%
# Change the date format of nc file ['appointment_date'].
# Convert date columns to datetime format
nc['appointment_date'] = pd.to_datetime(nc['appointment_date'])

# Sense-check the DataFrames with dtypes and head()
# View only appoitnment_date column in nc DateFrame and printing relevant info in easy read 
print("DataFrames after converting date columns to datetime format:")
print(nc['appointment_date'].head(5))  # Check the updated national_categories.xlsx DataFrame
# Out:
# DataFrames after converting date columns to datetime format:
# 0   2021-08-02
# 1   2021-08-02
# 2   2021-08-02
# 3   2021-08-02
# 4   2021-08-02
# Name: appointment_date, dtype: datetime64[ns]

# %%
# Determine the minimum and maximum dates in the ad DataFrame.
# Use appropriate docstrings.

# Identify the earliest and latest dates in the appointment scheduling column in ad DataFrame and print in easy read
min_appointment_date = ad['appointment_date'].min().date()
max_appointment_date = ad['appointment_date'].max().date()
print("Appointments were scheduled between", min_appointment_date, "and", max_appointment_date)
# Out:
# Appointments were scheduled between 2021-12-01 and 2022-06-30

# %%
# Determine the minimum and maximum dates in the nc DataFrame.
# Use appropriate docstrings.

# Identify the earliest and latest dates in the appointment scheduling column in nc DataFrame and print in easy read
min_appointment_date = nc['appointment_date'].min().date()
max_appointment_date = nc['appointment_date'].max().date()
print("Appointments were scheduled between", min_appointment_date, "and", max_appointment_date)
# Out:
# Appointments were scheduled between 2021-08-01 and 2022-06-30

# %% [markdown]
# The ad and the nc file report different dataset and consequentl differente dates. Firstly the datetime from both files were converted in a way were they had the same readable format, consequentlty were extraceted the info as from to when appoinments were shedule.
#
# For ad:Appointments were scheduled between 2021-12-01 and 2022-06-30
# For nc:Appointments were scheduled between 2021-08-01 and 2022-06-30.

# %% [markdown]
# **Question 2:** Which service setting was the most popular for NHS North West London from 1 January to 1 June 2022?

# %%
# Create a subset of the nc DataFrame
nc_subset = nc.copy()  # Make a copy to avoid modifying the original DataFrame

# Filter the subset based on the sub_icb_location code needed for NHS North West London
nc_subset = nc_subset[nc_subset['sub_icb_location_name'] == 'W2U3Z']

# Create and filter the subset based on the appointment date range given
start_date = pd.to_datetime('2022-01-01') # Start date
end_date = pd.to_datetime('2022-06-01')   # End date
nc_subset = nc_subset[(nc_subset['appointment_date'] >= start_date) & (nc_subset['appointment_date'] <= end_date)]
# Combine start and end date

# Count of unique values in the 'service_setting' column for the created new DataFrame
number_service_settings = nc.copy()['service_setting'].value_counts().idxmax()

# Print the result
print("Service with the most number of appoinments in North West London from 1 January to 1 June 2022:")
print(number_service_settings)
# Out:
# Service with the most number of appoinments in North West London from 1 January to 1 June 2022:
# General Practice

# %% [markdown]
# North West London was the practice in activity 2, q.2 with the highest number of records. Created a new data frame to avoid changing original data and using above steps was possible to identify thath the service setting more used in this clinic is General practice between the date mentioned.

# %% [markdown]
# **Question 3:** Which month had the highest number of appointments?

# %%
# Number of appointments per month == sum of count_of_appointments by month.
# Calculate the total number of appointments per month
appointments_per_month = nc['appointment_date'].dt.month.value_counts()

# Determine the total number of appointments per month
appointments_per_month = nc.groupby(nc['appointment_date'].dt.month_name ())['count_of_appointments'].sum()
print (appointments_per_month)

# Determine the total number of appointments per year
appointments_per_year = nc.groupby(nc['appointment_date'].dt.year)['count_of_appointments'].sum()
print(appointments_per_year)
# Out:
# appointment_date
# April        23913060
# August       23852171
# December     25140776
# February     25355260
# January      25635474
# June         25828078
# March        29595038
# May          27495508
# November     30405070
# October      30303834
# September    28522501
# Name: count_of_appointments, dtype: int64
# appointment_date
# 2021    138224352
# 2022    157822418
# Name: count_of_appointments, dtype: int64

# %%
# Sort the appointments based on count_of_appointments
sorted_monthly_appointments = appointments_per_month.sort_values(ascending=False)

# Get the month with the highest number of appointments
month_with_highest_appointments = sorted_monthly_appointments.index[0]

# Print the result
print("Month with the highest number of appointments:", month_with_highest_appointments)
# Out:
# Month with the highest number of appointments: November

# %% [markdown]
# From nc DataFrame identify the month with most number of appointments, not specifically for a given clinic.

# %% [markdown]
# **Question 4:** What was the total number of records per month?

# %%
# Total number of records per month.

nc.groupby(nc['appointment_date'].dt.month_name())[['count_of_appointments']].count()\
    .sort_values(by='count_of_appointments', ascending=False)
# Out:
#                   count_of_appointments
# appointment_date
# March                             82822
# November                          77652
# May                               77425
# September                         74922
# June                              74168
# October                           74078
# December                          72651
# January                           71896
# February                          71769
# April                             70012
# August                            69999

# %% [markdown]
# Using the same method above display the tot number of record x month: March is at the top, the other months are shown following a descending order.

# %% [markdown]
# #

# %% [markdown]
# # Assignment activity 4

# %% [markdown]
# ### Create visualisations and identify possible monthly and seasonal trends in the data.

# %%
# Import the necessary libraries.
import seaborn as sns
import matplotlib.pyplot as plt

# Set figure size.
sns.set(rc={'figure.figsize':(15, 12)})

# Set the plot style as white.
sns.set_style('white')

# %% [markdown]
# ### Objective 1
# Create three visualisations indicating the number of appointments per month for service settings, context types, and national categories.

# %% [markdown]
# **Service settings:**

# %%
# Create new nc copy DataFrame for service settings
nc_ss = nc.copy()  # Make a copy to avoid modifying the original DataFrame

# Change the data type of of appointment_month column to string to allow for easier plotting.
nc_ss['appointment_month'] = nc_ss['appointment_month'].astype(str)

# %%
#Groupby appoinment per month and service settings and determine the sum of appointments per month
nc_ss = nc.groupby(['appointment_month', 'service_setting'])['count_of_appointments'].sum().reset_index()

# View the new DataFrame
print(nc_ss)
# Out:
#    appointment_month            service_setting  count_of_appointments
# 0            2021-08  Extended Access Provision                 160927
# 1            2021-08           General Practice               21575852
# 2            2021-08                      Other                 449101
# 3            2021-08       Primary Care Network                 432448
# 4            2021-08                   Unmapped                1233843
# 5            2021-09  Extended Access Provision                 187906
# 6            2021-09           General Practice               25940821
# 7            2021-09                      Other                 527174
# 8            2021-09       Primary Care Network                 530485
# 9            2021-09                   Unmapped                1336115
# 10           2021-10  Extended Access Provision                 209539
# 11           2021-10           General Practice               27606171
# ...

# %%
# Plot the appointments over the available date range, and review the service settings for months.
# Create line plot for service settings

# Create the line plot with Seaborn with the determing variables
sns.lineplot(x='appointment_month', y='count_of_appointments', hue='service_setting', data=nc_ss, ci= None)
plt.xlabel('Month')
plt.ylabel('Number of Appointments')
plt.title('Number of Appointments per Month for Service Settings')

# Show the plot
plt.show()

# %% [markdown]
# In the plot above is possible to distinguish which service setting had that many appoinment number based on month. During 12 months cirlce the most utilized service is GP which remains as the most service indipendently from the month check, especially during oct-nov (possible flu?) and March (season allergy?). Would be interesting to check this trend deeper if needed.

# %% [markdown]
# **Context types:**

# %%
# Create new nc copy DataFrame for context type
nc_ct = nc.copy()  # Make a copy to avoid modifying the original DataFrame

# Change the data type of of appointment_month column to string to allow for easier plotting.
nc_ct['appointment_month'] = nc_ct['appointment_month'].astype(str)

# %%
#Groupby appoinment per month and context type and determine the sum of appointments per month
nc_ct = nc.groupby(['appointment_month', 'context_type'])['count_of_appointments'].sum().reset_index()

# View the new DataFrame
print(nc_ct)
# Out:
#    appointment_month            context_type  count_of_appointments
# 0            2021-08  Care Related Encounter               20255235
# 1            2021-08    Inconsistent Mapping                2363093
# 2            2021-08                Unmapped                1233843
# 3            2021-09  Care Related Encounter               24404251
# 4            2021-09    Inconsistent Mapping                2782135
# 5            2021-09                Unmapped                1336115
# 6            2021-10  Care Related Encounter               26125201
# 7            2021-10    Inconsistent Mapping                2811977
# 8            2021-10                Unmapped                1366656
# 9            2021-11  Care Related Encounter               26282778
# 10           2021-11    Inconsistent Mapping                2865796
# 11           2021-11                Unmapped                1256496
# 12           2021-12  Care Related Encounter               21798612
# ...

# %%
# Plot the appointments over the available date range, and review the context type for months.
# Create line plot for context type

# Create the line plot with Seaborn with the determing variables
sns.lineplot(x='appointment_month', y='count_of_appointments', hue='context_type', data=nc_ct, ci= None)
plt.xlabel('Month')
plt.ylabel('Number of Appointments')
plt.title('Number of Appointments per Month for Context Types')

# Show the plot
plt.show()

# %% [markdown]
# In the plot above is analyzed the context type over the same timeframe period as in the previous plot. In this case is possible to identify Care related encounter as the context types with major number of appointments, again this result is on the top for the the whole 12 month period. As describe in the metadata text categories within this context type involve the patient and can be any modality, e.g. face-to-face appointments, telephone consultations, video and online consultations, home visits etc.

# %% [markdown]
# **National categories:**

# %%
# Create new nc copy DataFrame for national categories
nc_nc = nc.copy()  # Make a copy to avoid modifying the original DataFrame

# Change the data type of of appointment_month column to string to allow for easier plotting.
nc_nc['appointment_month'] = nc_nc['appointment_month'].astype(str)

# %%
#Groupby appoinment per month and national categories and determine the sum of appointments per month
nc_nc = nc.groupby(['appointment_month', 'national_category'])['count_of_appointments'].sum().reset_index()

# View the new DataFrame
print(nc_nc)
# Out:
#     appointment_month  \
# 0             2021-08
# 1             2021-08
# 2             2021-08
# 3             2021-08
# 4             2021-08
# ..                ...
# 193           2022-06
# 194           2022-06
# 195           2022-06
# 196           2022-06
# 197           2022-06
#
#                                                        national_category  \
# 0    Care Home Needs Assessment & Personalised Care and Support Planning
# 1                                                        Care Home Visit
# 2                                                        Clinical Triage
# 3                                             General Consultation Acute
# 4                                           General Consultation Routine
# ..                                                                   ...
# 193                                           Social Prescribing Service
# 194                                         Structured Medication Review
# ...

# %%
# Plot the appointments over the available date range, and review the context type for months.
# Create line plot for national categories

# Create the line plot with Seaborn with the determing variables
sns.lineplot(x='appointment_month', y='count_of_appointments', hue='national_category', data=nc_nc, ci= None)
plt.xlabel('Month')
plt.ylabel('Number of Appointments')
plt.title('Number of Appointments per Month for National Categories')

# Show the plot
plt.show()

# %% [markdown]
# Following the point before, the above plot continue the analize of the previously managed data with more insight, under which category the appoinments took place: between the results is possible to find walk_in, home visit, care home visit, etc. The plot keep analyzing the same set of months and the category with most result over 12 months is General practice acute.

# %% [markdown]
# ### Objective 2
# Create four visualisations indicating the number of appointments for service setting per season. The seasons are summer (August 2021), autumn (October 2021), winter (January 2022), and spring (April 2022).

# %% [markdown]
# **Summer (August 2021):**

# %%
# Create new nc copy DataFrame for service settings to be utilized for the seasons
# Groupby appoinment per date, month and service settings and determine the sum of appointments per month with the reset of index
# Filter the data for the summer season (August 2021)

nc_ss_day = nc.groupby(['appointment_date','appointment_month','service_setting'])['count_of_appointments'].sum().reset_index()
summer_data = nc_ss_day[nc_ss_day['appointment_month'] == '2021-08']
print (summer_data)
# Out:
#     appointment_date appointment_month            service_setting  \
# 0         2021-08-01           2021-08  Extended Access Provision
# 1         2021-08-01           2021-08           General Practice
# 2         2021-08-01           2021-08                      Other
# 3         2021-08-01           2021-08       Primary Care Network
# 4         2021-08-01           2021-08                   Unmapped
# ..               ...               ...                        ...
# 150       2021-08-31           2021-08  Extended Access Provision
# 151       2021-08-31           2021-08           General Practice
# 152       2021-08-31           2021-08                      Other
# 153       2021-08-31           2021-08       Primary Care Network
# 154       2021-08-31           2021-08                   Unmapped
#
#      count_of_appointments
# 0                      438
# 1                     3411
# 2                      401
# 3                      323
# 4                     1054
# ...

# %%
# Look at August 2021 in more detail to allow a closer look.
# Create a lineplot with Seaborn.

# Create line plot for the summer season
sns.lineplot(x='appointment_date', y='count_of_appointments', hue='service_setting', data=summer_data, ci=None)
plt.xlabel('Date')
plt.ylabel('Number of Appointments')
plt.title('Number of Appointments for Service Setting - Summer Season')
plt.show()

# %% [markdown]
# Following the same logic applied before four other line plots have been created. For the four seasons of the year have been allocated one month each season and the intented is to have a deeper look if the service setting most used during the four season change, have a pattern or there is need to check more in detail.
#
# The first graph show the month of August which has been refer as the summer season. The dates represented in this case, as only one month is analyzed, are referred are days of the month and 8 as August compared to the number of appoitments.. From the lineplot is easy to idenify that GP is the most used service with more number of appoitnmentsduring the month of August.

# %% [markdown]
# **Autumn (October 2021):**

# %%
# Groupby appoinment per date, month and service settings and determine the sum of appointments per month with the reset of index
# Filter the data for the autumn season (October 2021)

nc_ss_day = nc.groupby(['appointment_date','appointment_month', 'service_setting'])['count_of_appointments'].sum().reset_index()
autumn_data = nc_ss_day[nc_ss_day['appointment_month'] == '2021-10']
print (autumn_data)
# Out:
#     appointment_date appointment_month            service_setting  \
# 305       2021-10-01           2021-10  Extended Access Provision
# 306       2021-10-01           2021-10           General Practice
# 307       2021-10-01           2021-10                      Other
# 308       2021-10-01           2021-10       Primary Care Network
# 309       2021-10-01           2021-10                   Unmapped
# ..               ...               ...                        ...
# 455       2021-10-31           2021-10  Extended Access Provision
# 456       2021-10-31           2021-10           General Practice
# 457       2021-10-31           2021-10                      Other
# 458       2021-10-31           2021-10       Primary Care Network
# 459       2021-10-31           2021-10                   Unmapped
#
#      count_of_appointments
# 305                   7107
# 306                1130646
# 307                  22639
# 308                  22974
# 309                  56201
# ...

# %%
# Look at October 2021 in more detail to allow a closer look.
# Create a lineplot with Seaborn.

# Create line plot for the autumn season
sns.lineplot(x='appointment_date', y='count_of_appointments', hue='service_setting', data=autumn_data, ci=None)
plt.xlabel('Date')
plt.ylabel('Number of Appointments')
plt.title('Number of Appointments for Service Setting - Autumn Season')
plt.show()

# %% [markdown]
# In this line plot the month analyzed is October which is referres as the Autumn season. The following plot for the coming seasons (autumn, winter, spring) are comparis to the first line plot of the season and the same data set is consider, the only thing which differ is the month and cosequenlty the season. For autumn season Gp is still the service with most appoitments (orange line).

# %% [markdown]
# **Winter (January 2022):**

# %%
# Groupby appoinment per date, month and service settings and determine the sum of appointments per month with the reset of index
# Filter the data for the winter season (January 2022)

nc_ss_day = nc.groupby(['appointment_date','appointment_month', 'service_setting'])['count_of_appointments'].sum().reset_index()
winter_data = nc_ss_day[nc_ss_day['appointment_month'] == '2022-01']
print (winter_data)
# Out:
#     appointment_date appointment_month            service_setting  \
# 765       2022-01-01           2022-01  Extended Access Provision
# 766       2022-01-01           2022-01           General Practice
# 767       2022-01-01           2022-01                      Other
# 768       2022-01-01           2022-01       Primary Care Network
# 769       2022-01-01           2022-01                   Unmapped
# ..               ...               ...                        ...
# 915       2022-01-31           2022-01  Extended Access Provision
# 916       2022-01-31           2022-01           General Practice
# 917       2022-01-31           2022-01                      Other
# 918       2022-01-31           2022-01       Primary Care Network
# 919       2022-01-31           2022-01                   Unmapped
#
#      count_of_appointments
# 765                    246
# 766                   3578
# 767                    280
# 768                    215
# 769                    572
# ...

# %%
# Look at January 2022 in more detail to allow a closer look.
# Create a lineplot with Seaborn.

# Create line plot for the winter season
sns.lineplot(x='appointment_date', y='count_of_appointments', hue='service_setting', data=winter_data, ci=None)
plt.xlabel('Date')
plt.ylabel('Number of Appointments')
plt.title('Number of Appointments for Service Setting - Winter Season')
plt.show()

# %% [markdown]
# Nothing new to consider on the Winter season referred to which Jan 2022, again the orange line seems to be appearing as the most used service.

# %% [markdown]
# **Spring (April 2022):**

# %%
# Groupby appoinment per date, month and service settings and determine the sum of appointments per month with the reset of index
# Filter the data for the spring season (April 2022)

nc_ss_day = nc.groupby(['appointment_date','appointment_month', 'service_setting'])['count_of_appointments'].sum().reset_index()
spring_data = nc_ss_day[nc_ss_day['appointment_month'] == '2022-04']
print (spring_data)
# Out:
#      appointment_date appointment_month            service_setting  \
# 1215       2022-04-01           2022-04  Extended Access Provision
# 1216       2022-04-01           2022-04           General Practice
# 1217       2022-04-01           2022-04                      Other
# 1218       2022-04-01           2022-04       Primary Care Network
# 1219       2022-04-01           2022-04                   Unmapped
# ...               ...               ...                        ...
# 1360       2022-04-30           2022-04  Extended Access Provision
# 1361       2022-04-30           2022-04           General Practice
# 1362       2022-04-30           2022-04                      Other
# 1363       2022-04-30           2022-04       Primary Care Network
# 1364       2022-04-30           2022-04                   Unmapped
#
#       count_of_appointments
# 1215                   8011
# 1216                1085037
# 1217                  21077
# 1218                  26493
# ...

# %%
# Look at April 2022 in more detail to allow a closer look.
# Create a lineplot with Seaborn.

# Create line plot for the sprint season
sns.lineplot(x='appointment_date', y='count_of_appointments', hue='service_setting', data=spring_data, ci=None)
plt.xlabel('Date')
plt.ylabel('Number of Appointments')
plt.title('Number of Appointments for Service Setting - Sprint Season')
plt.show()

# %% [markdown]
# Following the same logic applied for the previous season in the last plot spring (April) is represented. Again GP is has the most relevant result.

# %% [markdown]
# # Assignment activity 5

# %% [markdown]
# ### Analyse tweets from Twitter with hashtags related to healthcare in the UK.

# %%
# Libraries and settings needed for analysis
import pandas as pd
import seaborn as sns

# Set figure size.
sns.set(rc={'figure.figsize':(15, 12)})

# Set the plot style as white.
sns.set_style('white')

# Maximum column width to display
pd.options.display.max_colwidth = 200

# %%
# Load the tweets.csv file into a DataFrame
tweets = pd.read_csv('tweets.csv')

# View the DataFrame.
print(tweets.head())
# Out:
#               tweet_id  \
# 0  1567629223795527681
# 1  1567582846612553728
# 2  1567582787070304256
# 3  1567582767625428992
# 4  1567582720460570625
#
#                                                                                                                                                                                            tweet_full_text  \
# 0  As Arkansas’ first Comprehensive Stroke Certified Center, UAMS provides Arkansans with access to the most advanced stoke care. Join us in our mission to make a difference in the health and well-be...
# 1                                                              RT @AndreaGrammer: Work-life balance is at the foundation of how decisions are made and where #PremiseHealth is headed.  We're #hiring for…
# 2                                                           RT @OntarioGreens: $10 billion can go a long way to fixing our broken #Healthcare system.\n\nYet Doug Ford would rather spend it ALL on a hig…
# ...

# %% [markdown]
# Load the inherent file and view the first 5 rows to start exploring the data.

# %%
# Explore the data set
# Explore the metadata.

# Summary statistics of the DataFrame
print(tweets.describe())

# Information about the DataFrame
print(tweets.info())
# Out:
#            tweet_id  tweet_retweet_count  tweet_favorite_count
# count  1.174000e+03          1174.000000            1174.00000
# mean   1.567612e+18             8.629472               0.37138
# std    2.427553e+13            29.784675               2.04470
# min    1.567574e+18             0.000000               0.00000
# 25%    1.567590e+18             0.000000               0.00000
# 50%    1.567611e+18             1.000000               0.00000
# 75%    1.567633e+18             3.000000               0.00000
# max    1.567655e+18           303.000000              42.00000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1174 entries, 0 to 1173
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tweet_id                 1174 non-null   int64
#  1   tweet_full_text          1174 non-null   object
#  2   tweet_entities           1174 non-null   object
# ...

# %% [markdown]
# Start to explore the date with the describe and info function.

# %%
# Would it be useful to only look at retweeted and favourite tweet messages?
# Explain your answer (on the report).

# Count the occurrences of each value in the tweet_retweet_count column
print(tweets['tweet_retweet_count'].value_counts())

# Count the occurrences of each value in the tweet_favorite_count column
print(tweets['tweet_favorite_count'].value_counts())
# Out:
# 0      526
# 1      215
# 2      114
# 3       70
# 5       35
# 4       27
# 7       18
# 12      16
# 8       15
# 73      14
# 9       13
# 6       12
# 208     12
# 35      10
# 37       6
# 11       6
# 10       5
# 53       5
# 44       4
# 150      4
# 63       4
# 76       3
# 85       3
# 41       3
# 62       3
# 207      3
# 68       3
# 78       2
# 23       2
# 24       2
# 72       2
# 16       2
# 13       1
# 49       1
# 48       1
# 15       1
# 107      1
# 14       1
# 79       1
# 20       1
# 39       1
# 19       1
# 303      1
# 57       1
# 40       1
# 54       1
# 169      1
# Name: tweet_retweet_count, dtype: int64
# 0     1027
# 1       91
# 2       16
# 3       13
# 4        7
# 5        5
# 6        2
# 17       1
# 12       1
# 10       1
# 8        1
# 13       1
# 11       1
# 7        1
# 20       1
# 28       1
# 14       1
# 18       1
# 9        1
# 42       1
# Name: tweet_favorite_count, dtype: int64

# %% [markdown]
# Use the value function on the retweet count and retweet favourite count coloumns. During this fuction is taking in consideration only the number of values which is not impacting the process of undertanding the data. From a markeing prospective it will be beneficial to read the actual text of these retweets and favourite tweets. Tweets are generelly used to comment, so in this case cheking the relevant tweets can be advantageos to understand if there are complains or Nhs service are satisfing among the comunity.

# %%
# Create a new DataFrame containing only the text.
tweets_text = tweets[['tweet_full_text']].copy()

# View the DataFrame.
tweets_text.head()
# Out:
#                                                                                                                                                                                            tweet_full_text
# 0  As Arkansas’ first Comprehensive Stroke Certified Center, UAMS provides Arkansans with access to the most advanced stoke care. Join us in our mission to make a difference in the health and well-be...
# 1                                                              RT @AndreaGrammer: Work-life balance is at the foundation of how decisions are made and where #PremiseHealth is headed.  We're #hiring for…
# 2                                                           RT @OntarioGreens: $10 billion can go a long way to fixing our broken #Healthcare system.\n\nYet Doug Ford would rather spend it ALL on a hig…
# ...

# %% [markdown]
# Create a new df to explore the hashtags texts.

# %%
tags = [] #Create an emtpy list

# %%
# Loop through the messages, and create a list of values containing the # symbol.
for y in [x.split(' ') for x in tweets['tweet_full_text'].values]:
    for z in y:
        if '#' in z:
            # Change to lowercase.
            tags.append(z.lower())

# %%
#Create a list to count the values in the list
tags = pd.Series(tags)

# Count the occurrences of each tag
tags_counts = tags.value_counts()

# Print the tag counts
print(tags_counts)
# Out:
# #healthcare      716
# #health           80
# #medicine         41
# #ai               40
# #job              38
#                 ...
# #evestudy          1
# #patientdata…      1
# #secure            1
# #sms               1
# \n#csjmu           1
# Length: 1754, dtype: int64

# %%
# Display the first 30 records.
print(tags_counts[:30])
# Out:
# #healthcare                    716
# #health                         80
# #medicine                       41
# #ai                             40
# #job                            38
# #medical                        35
# #strategy                       30
# #pharmaceutical                 28
# #digitalhealth                  25
# #pharma                         25
# #marketing                      25
# #medtwitter                     24
# #biotech                        24
# #competitiveintelligence        24
# #meded                          23
# #vaccine                        18
# #hiring                         18
# #news                           17
# #machinelearning                17
# #technology                     17
# #coronavirus                    16
# #womeninmedicine                16
# #covid                          16
# #competitivemarketing           16
# #wellness                       15
# #healthtech                     15
# #doctorofveterinarymedicine     14
# ...

# %% [markdown]
# Visualize the most relevant hashtags, the first top 30.

# %%
# Convert the series to a DataFrame in preparation for visualisation.
data = pd.DataFrame(tags_counts).reset_index()

data.head()
# Out:
#          index    0
# 0  #healthcare  716
# 1      #health   80
# 2    #medicine   41
# 3          #ai   40
# 4         #job   38

# %%
# Rename the columns.
data.columns = ['word','count']
data.head()
# Out:
#           word  count
# 0  #healthcare    716
# 1      #health     80
# 2    #medicine     41
# 3          #ai     40
# 4         #job     38

# %%
#Ensure the count data type is integer
data['count'] = data['count'].astype(int)

# %%
# Sense-check the column names, number of rows and columns, data types
print('data')
print(data.columns)  #Column names
print(data.shape)    #Number of rows and columns
print(data.dtypes)   #Data types
# Out:
# data
# Index(['word', 'count'], dtype='object')
# (1754, 2)
# word     object
# count     int64
# dtype: object

# %%
# Display records where the count is larger than 10.
filtered_data = data[data['count'] > 10]

# %% [markdown]
# After have converted the tgs series into a DataFrame, rename the coloumns, fix the integer and filter the data that has more than 10 count on each hashtags.

# %%
#Create a seaborn barplot for the most used #
sns.barplot(x='count', y='word', data=filtered_data)
plt.xlabel('Count')
plt.ylabel('word')
plt.title('Top Trending Hashtags')
plt.show()

# %% [markdown]
# Show on the plot created from the data above. The bar plot is used to represent the most used hashtags inherent to Twitter on NHS. From the top the most used ones, at the top being helthcare. Reading towards down in descending order the hashtags to follow. On the opposite axis represented the ammount in which the hashtags are used.
# As the size was aready given as a setup this was not fixed.

# %%
#Create a seaborn barchart to improve the visualization of the data above
top_hashtags= filtered_data.sort_values(by='count',ascending=False).head(10)

sns.barplot(x='count', y='word', data=top_hashtags)
plt.xlabel('Count')
plt.ylabel('Word')
plt.title('Most Frequently Used Hashtags')
plt.show()

# %% [markdown]
# The barplot above focus limiting the visualization for the most used 10 hashtags to give a better insight.

# %% [markdown]
# #

# %% [markdown]
# # Assignment activity 6

# %% [markdown]
# ### Investigate the main cencerns posed by the NHS.

# %%
# Prepare your workstation.
# Load the appointments_regional.csv file.
ar = pd.read_csv('appointments_regional.csv')

# View the DataFrame.
ar.head()
# Out:
#   icb_ons_code appointment_month appointment_status hcp_type appointment_mode  \
# 0    E54000034           2020-01           Attended       GP     Face-to-Face
# 1    E54000034           2020-01           Attended       GP     Face-to-Face
# 2    E54000034           2020-01           Attended       GP     Face-to-Face
# 3    E54000034           2020-01           Attended       GP     Face-to-Face
# 4    E54000034           2020-01           Attended       GP     Face-to-Face
#
#   time_between_book_and_appointment  count_of_appointments
# 0                             1 Day                   8107
# 1                    15  to 21 Days                   6791
# 2                       2 to 7 Days                  20686
# 3                    22  to 28 Days                   4268
# 4                     8  to 14 Days                  11971

# %%
# Print the min and max dates.
print("Minimum date:", ar['appointment_month'].min())
print("Maximum date:", ar['appointment_month'].max())
# Out:
# Minimum date: 2020-01
# Maximum date: 2022-06

# %%
# Filter the data set to only look at data from 2021-08 onwards.
ar_filtered = ar[ar['appointment_month'] >= '2021-08']
# Print the DataFrame.
ar_filtered.head()
# Out:
#      icb_ons_code appointment_month appointment_status hcp_type  \
# 3652    E54000034           2021-08           Attended       GP
# 3653    E54000034           2021-08           Attended       GP
# 3654    E54000034           2021-08           Attended       GP
# 3655    E54000034           2021-08           Attended       GP
# 3656    E54000034           2021-08           Attended       GP
#
#      appointment_mode time_between_book_and_appointment  count_of_appointments
# 3652     Face-to-Face                             1 Day                   6553
# 3653     Face-to-Face                    15  to 21 Days                   2390
# 3654     Face-to-Face                       2 to 7 Days                  10547
# 3655     Face-to-Face                    22  to 28 Days                    937
# 3656     Face-to-Face                     8  to 14 Days                   4961

# %% [markdown]
# **Question 1:** Should the NHS start looking at increasing staff levels?

# %%
ar_agg = ar_filtered[['appointment_month', 'hcp_type', 'appointment_status', 'appointment_mode', 'time_between_book_and_appointment','count_of_appointments']]

# %%
ar_agg = ar_filtered.groupby(['appointment_month', 'hcp_type', 'appointment_status', 'appointment_mode', 'time_between_book_and_appointment'])['count_of_appointments'].sum().reset_index()
ar_agg
# Out:
#      appointment_month hcp_type appointment_status appointment_mode  \
# 0              2021-08       GP           Attended     Face-to-Face
# 1              2021-08       GP           Attended     Face-to-Face
# 2              2021-08       GP           Attended     Face-to-Face
# 3              2021-08       GP           Attended     Face-to-Face
# 4              2021-08       GP           Attended     Face-to-Face
# ...                ...      ...                ...              ...
# 3749           2022-06  Unknown            Unknown          Unknown
# 3750           2022-06  Unknown            Unknown          Unknown
# 3751           2022-06  Unknown            Unknown          Unknown
# 3752           2022-06  Unknown            Unknown          Unknown
# 3753           2022-06  Unknown            Unknown     Video/Online
#
#      time_between_book_and_appointment  count_of_appointments
# 0                                1 Day                 507835
# ...

# %%
# Determine the total number of appointments per month.
#Create a new data frame ar_df
#Use Groupby function to calculate number of appointments per month 
ar_df = ar_filtered.groupby('appointment_month')['count_of_appointments'].sum().reset_index()

# Add a new column to indicate the average utilisation of services to calculate average appointment per day on 30days month
# Monthly aggregate / 30 to get to a daily value.
ar_df['utilisation'] = ar_df['count_of_appointments'] / 30  # Assuming 30 days in a month

max_capacity = 1200000 #Max capacity per day
ar_df['utilisation'] = ar_df['utilisation'].round(1) #Show only 1 decimal

# View the DataFrame.
print(ar_df)
# Out:
#    appointment_month  count_of_appointments  utilisation
# 0            2021-08               23852171     795072.4
# 1            2021-09               28522501     950750.0
# 2            2021-10               30303834    1010127.8
# 3            2021-11               30405070    1013502.3
# 4            2021-12               25140776     838025.9
# 5            2022-01               25635474     854515.8
# 6            2022-02               25355260     845175.3
# 7            2022-03               29595038     986501.3
# 8            2022-04               23913060     797102.0
# 9            2022-05               27495508     916516.9
# 10           2022-06               25828078     860935.9

# %%
ar_agg['appointment_month'] = ar_agg['appointment_month'].astype(str)
ar_df['appointment_month'] = ar_df['appointment_month'].astype(str)

import seaborn as sns
import matplotlib.pyplot as plt

# Set figure size.
sns.set(rc={'figure.figsize':(15, 12)})

# Set the plot style as white.
sns.set_style('white')

sns.lineplot(data=ar_agg, x='appointment_month', y='count_of_appointments',ci=None)
plt.xlabel('Appointment Month')
plt.ylabel('Number of Appointments')
plt.title('Number of Monthly Visits')
plt.show()

sns.lineplot(data=ar_df, x='appointment_month', y='utilisation', ci=None)
plt.axhline(y=max_capacity, color='red', linestyle='--', label='Maximum Capacity')
plt.xlabel('Appointment Month')
plt.ylabel('Utilization')
plt.title('Monthly Capacity Utilization')
plt.legend()
plt.show()

# %% [markdown]
# Already from the lineplots in objective 1 in the assignment 4 it was possible to notice the peak of the appointments during the months of Oct-Nov and March maybe due to season illnesses.
# The same results are confirmed on the first lineplot where is shown the average utilisation of services calculating the ammount of appoinments divided into 30 days of the month.
#
# In the second lineplot is set up a limit of appointments at 1200000 as max capacity per day. If this number is used as a guideline for appoinment capacity based on staff then possibly staff is well allocated to respond to clients request. Worth make sure having a staff backup in case of any urgency or unexpected situation for the months with most appoinments booked.

# %% [markdown]
# **Question 2:** How do the healthcare professional types differ over time?

# %%
# Create a line plot to answer the question.
# Set figure size.
sns.set(rc={'figure.figsize':(15, 12)})

# Set the plot style as white.
sns.set_style('white')

sns.lineplot(data=ar_agg, x='appointment_month', y='count_of_appointments', hue='hcp_type', ci=None)
plt.xlabel('Appointment Month')
plt.ylabel('Number of Appointments')
plt.title('Healthcare Professional Types over Time')
plt.legend(title='Healthcare Professional Type')
plt.show()

# %% [markdown]
# In the line plot above are considered the different types of heathcare professional types over the different months (Aug21-Jun22). General practice in blue seems to be the most used one, althought during october other practices seems having more appointments booked (orange), possible cause can be seasonal vaccination?

# %% [markdown]
# **Question 3:** Are there significant changes in whether or not visits are attended?

# %%
# Create a line plot to answer the question.
# Set figure size.
sns.set(rc={'figure.figsize':(15, 12)})

# Set the plot style as white.
sns.set_style('white')

sns.lineplot(data=ar_agg, x='appointment_month', y='count_of_appointments', hue='appointment_status', ci=None)
plt.xlabel('Appointment Month')
plt.ylabel('Number of Appointments')
plt.title('Attendance of Visits over Time')
plt.legend(title='Appointment Status')
plt.show()

# %% [markdown]
# In the plot above is illustrated data on if patients attend the appointments.
# Mostly appoitments are attended. If consider the axis with the number of appointments the numbers gaps are 5k to 5k. In this case the unknown and non attended (although are minor to the attended ones) are significatly having an impact on the organization  schedule. In first place it's needed to investigate why there is a dataset for unknown, someone should be allocated to eliminated this data and clear it reporting on only attended or not attended. In second place consider that the non attended appoinments impact on the budget and results and try to find solutions such as sending reminders or proposing alternative solutions to correct this behaviour.

# %% [markdown]
# **Question 4:** Are there changes in terms of appointment type and the busiest months?

# %%
# Create a line plot to answer the question.
# Set figure size.
sns.set(rc={'figure.figsize':(15, 12)})

# Set the plot style as white.
sns.set_style('white')

sns.lineplot(data=ar_agg, x='appointment_month', y='count_of_appointments', hue='appointment_mode', ci=None)
plt.xlabel('Appointment Month')
plt.ylabel('Number of Appointments')
plt.title('Appointment Types and Busiest Months')
plt.legend(title='Appointment Mode')
plt.show()

# %% [markdown]
# Keep working on the prvious data set the above lineplot investigate on the appointment type. If the previous considerations are correct, where other clinical activities surpass gp, in october the face to face is inhevitable in case of vaccination requested. Telephone practise seems still to be in a good place. Unknown data is again present on this chard and seems higher that video call, something to be investigated. Videocalls seems to be the least appealing one, consequently allocate maybe more staff to face to face clinic instead of digital and reconsider the costs involved in digital trainig or elsewise launch a system more friendly (online) and promote it on platforms, for instance on the social network (Twitter) to also have more visul among the community.

# %% [markdown]
# **Question 5:** Are there any trends in time between booking an appointment?

# %%
# Create a line plot to answer the question.
# Set figure size.
sns.set(rc={'figure.figsize':(15, 12)})

# Set the plot style as white.
sns.set_style('white')

sns.lineplot(data=ar_agg, x='appointment_month', y='time_between_book_and_appointment',ci=None)
plt.xlabel('Appointment Month')
plt.ylabel('Time Between Booking and Appointment')
plt.title('Trends in Time Between Booking and Appointment')
plt.show()

# %% [markdown]
# Wold suggest to use a more efficient plot and to record the data in a more suitable way. The graph above is meant to report the waiting time between booking and appoinment. The data has been cleaned before representing but the paraments used is not satisfying.
# Results given show more waiting time between oct-now and less in march.

# %% [markdown]
# **Question 6:** How do the spread of service settings compare?

# %%
# Let's go back to the national category DataFrame you created in an earlier assignment activity.
nc = pd.read_excel('national_categories.xlsx')
nc.head()
# Out:
#   appointment_date icb_ons_code                       sub_icb_location_name  \
# 0       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 1       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 2       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 3       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 4       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
#
#         service_setting            context_type  \
# 0  Primary Care Network  Care Related Encounter
# 1                 Other  Care Related Encounter
# 2      General Practice  Care Related Encounter
# 3      General Practice  Care Related Encounter
# 4      General Practice  Care Related Encounter
#
#                         national_category  count_of_appointments  \
# 0  Patient contact during Care Home Round                      3
# 1                         Planned Clinics                      7
# ...

# %%
#Create a new dataframe and group appointment month and number of appoitments
#For personal choice added also a group on service settings for eascy compare
nc_appointment_bymonth = nc.groupby(['appointment_month','service_setting']).sum()['count_of_appointments'].reset_index()

#View the new dataframe
nc_appointment_bymonth.head()
# Out:
#   appointment_month            service_setting  count_of_appointments
# 0           2021-08  Extended Access Provision                 160927
# 1           2021-08           General Practice               21575852
# 2           2021-08                      Other                 449101
# 3           2021-08       Primary Care Network                 432448
# 4           2021-08                   Unmapped                1233843

# %%
#Create a suitable visualization in Seaborn with given size, colour
#Created the visutalization as  a boxplot to investigate spread of service settings.

# Set the size.
plt.figure(figsize=(15,12))
# Set the plot style as white.
sns.set_style('white')

sns.boxplot(data=nc_appointment_bymonth, x='service_setting',y='count_of_appointments')
plt.xlabel('Service settings')
plt.ylabel('Number of Appointments')
plt.title('Comparison of Service Settings')
plt.show()

# %% [markdown]
# In the plot above are reported the diffent practice activitythe numbers only compared to the count of appoinments in none timeline using the function groupby. Gp seems to be the most used. Other activities are relevant but little hard to read them.

# %%
# Create a new dataframe to investigate a new boxplot for service settings without GP.
non_gp_df = nc_appointment_bymonth[nc_appointment_bymonth['service_setting'] != 'General Practice']
non_gp_df.head()
# Out:
#   appointment_month            service_setting  count_of_appointments
# 0           2021-08  Extended Access Provision                 160927
# 2           2021-08                      Other                 449101
# 3           2021-08       Primary Care Network                 432448
# 4           2021-08                   Unmapped                1233843
# 5           2021-09  Extended Access Provision                 187906

# %%
#Groupby the new dataframe resetting the index and with relevant columns.
non_gpdf = non_gp_df.groupby(['appointment_month', 'service_setting']).sum()['count_of_appointments'].reset_index()
non_gpdf.head()
# Out:
#   appointment_month            service_setting  count_of_appointments
# 0           2021-08  Extended Access Provision                 160927
# 1           2021-08                      Other                 449101
# 2           2021-08       Primary Care Network                 432448
# 3           2021-08                   Unmapped                1233843
# 4           2021-09  Extended Access Provision                 187906

# %%
#Create a suitable visualization in Seaborn with given size, colour for service setting without GP
#Created the visutalization as  a boxplot to investigate spread of service settings.
sns.boxplot(data=non_gpdf, x='service_setting', y='count_of_appointments')
plt.xlabel('Appoitment Month')
plt.ylabel('Number of Appointments')
plt.title('Comparison of Service Settings')
plt.show()

# %% [markdown]
# The above boxplot is used to investigate the non clear box plot from the one above, consequelty Gp has been removed.

# %% [markdown]
# #

# %% [markdown]
# ### Provide a summary of your findings and recommendations based on the analysis.

# %% [markdown]
# > Double click to insert your summary.

# %% [markdown]
# Throgh the datasets provided the study above try to delve deeper into the data, considering contextual information, patterns, and other relevant factors, being technical rigor and critical analysis. It aims for a concise and direct approach, highlighting specific steps taken, checkpoints, and verifiable results.
#
# Regarding the analytical process, it is crucial to clarify doubts and uncertainties. Some doubts were encountered, and emplored criteria for decision-making, specifally which data points to retained, and the margin of error.
#
# In terms of insights, data were explore from various perspectives (different graphs and different datasets) and present information in a way that allows business users to gain deeper insights beyond basic reporting. This includes analyzing quantitative and relative patterns and providing specific recommendations for implementing actions in the business.
#
# To improve the reporting, in the future is suggested to collect the data in a more organized manner, excluding unknown or unreliable data, and focusing on areas that offer greater exploration opportunities. Notably, during October-November and March, the NHS experiences a significant number of bookings, warranting a reassessment of staffing levels and the need for backup during those months. While GP services appear to be the most utilized, it should be also investigate other relevant activities in October and determine which services the patients were using.
#
# It is essential to enhance the data collection process by capturing information on the time frame between booking and appointment. This will help identify any existing issues. Although the default appointment capacity is set to a maximum, it is noteworthy that the actual number of appointments never reaches this limit, indicating that the NHS is not overwhelmed with bookings.
#
# It has been observed higher appointment numbers during certain months, raising questions about the possible influence of seasonal illnesses or vaccination requirements. Some data points still contain unknown values, making interpretation difficult. However, it was decided to retained this data as it is deemed essential for the investigation and can potentially provide valuable insights.
#
# Given the potential margin for error in the data, we should exercise caution when drawing conclusions. It may be beneficial to represent certain data points using different graph types to explore alternative patterns or relationships.
